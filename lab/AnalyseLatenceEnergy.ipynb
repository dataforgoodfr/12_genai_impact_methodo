# %%
from IPython.display import display
import pandas as pd

llm_perf = pd.read_csv('data/llm_perf_filtered.csv')
ml_energy = pd.read_csv('data/aggregated_ml_energy.csv')

display(llm_perf)
display(ml_energy)
# Out:
#      Unnamed: 0                          model  throughput  response_length  \
# 0             0        EleutherAI/gpt-neox-20b        27.4              256
# 1             5          EleutherAI/pythia-12b        36.6              256
# 2             7  EleutherAI/pythia-12b-deduped        36.6              256
# 3            10   EleutherAI/polyglot-ko-12.8b        33.4              256
# 4            25        DevaMalla/llama-base-7b        39.1              256
# ..          ...                            ...         ...              ...
# 263        1595          huggingface/llama-13b        28.5              256
# 264        1599            fblgit/una-llama-7b        35.8              256
# 265        1600      codellama/CodeLlama-7b-hf        36.7              256
# 266        1601     codellama/CodeLlama-13b-hf        29.0              256
# 267        1602     codellama/CodeLlama-34b-hf        22.7              256
#
#      latency    energy                    gpu  task  parameters_count  \
# 0       9.34  3013.632  NVIDIA A100-SXM4-80GB  chat              20.0
# 1       6.99  2101.248  NVIDIA A100-SXM4-80GB  chat              12.0
# 2       7.00  2082.816  NVIDIA A100-SXM4-80GB  chat              12.0
# 3       7.67  2313.216  NVIDIA A100-SXM4-80GB  chat              12.8
# 4       6.54  1815.552  NVIDIA A100-SXM4-80GB  chat               7.0
# ..       ...       ...                    ...   ...               ...
# 263     8.97  2534.400  NVIDIA A100-SXM4-80GB  chat              13.0
# 264     7.15  1833.984  NVIDIA A100-SXM4-80GB  chat               7.0
# 265     6.97  1870.848  NVIDIA A100-SXM4-80GB  chat               7.0
# 266     8.82  2515.968  NVIDIA A100-SXM4-80GB  chat              13.0
# 267    11.30  3861.504  NVIDIA A100-SXM4-80GB  chat              34.0
#
#      energy_per_token    dtype  optimization          quantization  cuda-fp16
# 0             0.00327  float16           NaN  gptq-4bit+exllama-v1      False
# 1             0.00228  float16           NaN  gptq-4bit+exllama-v1      False
# 2             0.00226  float16           NaN  gptq-4bit+exllama-v1      False
# 3             0.00251  float16           NaN  gptq-4bit+exllama-v1      False
# 4             0.00197  float16           NaN  gptq-4bit+exllama-v1      False
# ..                ...      ...           ...                   ...        ...
# 263           0.00275  float16           NaN         awq-4bit+gemm      False
# 264           0.00199  float16           NaN         awq-4bit+gemm      False
# 265           0.00203  float16           NaN         awq-4bit+gemm      False
# 266           0.00273  float16           NaN         awq-4bit+gemm      False
# 267           0.00419  float16           NaN         awq-4bit+gemm      False
#
# [268 rows x 14 columns]
#                                         model  throughput  response_length  \
# 0                              BAIR/koala-13b   25.501170       258.854265
# 1                               BAIR/koala-7b   32.927217       247.045668
# 2                          RWKV/rwkv-raven-7b   64.478527       209.478845
# 3    FreedomIntelligence/phoenix-inst-chat-7b   54.276457       233.511081
# 4            camel-ai/CAMEL-13B-Combined-Data   26.300221       282.480188
# ..                                        ...         ...              ...
# 255                           metaai/llama-7B   23.642990       110.302552
# 256                       tatsu-lab/alpaca-7B   31.257538       127.870047
# 257                             BAIR/koala-7b   31.414144       253.603761
# 258                        RWKV/rwkv-raven-7b   39.939984       246.796508
# 259                Salesforce/xgen-7b-8k-inst   37.606060       273.058764
#
#        latency       energy   gpu          task  parameters_count  \
# 0    10.063551  1946.198744  A100  chat-concise                13
# 1     7.462044  1195.704790  A100  chat-concise                 7
# 2     2.921289   736.655330  A100  chat-concise                 7
# 3     4.103907  1002.328573  A100  chat-concise                 7
# 4    10.727640  2349.183088  A100  chat-concise                13
# ..         ...          ...   ...           ...               ...
# 255   3.730666   636.401785  V100      instruct                 7
# 256   3.985343   671.828829  V100      instruct                 7
# 257   7.832867  1181.363735  V100      instruct                 7
# 258   5.837914  1302.030667  V100      instruct                 7
# 259   7.299936  1329.685454  V100      instruct                 7
#
#      energy_per_token    dtype optimization quantization  cuda-fp16
# 0            0.002088  float16         None         None      False
# 1            0.001344  float16         None         None      False
# 2            0.000977  float16         None         None      False
# 3            0.001192  float16         None         None      False
# 4            0.002310  float16         None         None      False
# ..                ...      ...          ...          ...        ...
# 255          0.001603  float16         None         None      False
# 256          0.001459  float16         None         None      False
# 257          0.001294  float16         None         None      False
# 258          0.001465  float16         None         None      False
# 259          0.001353  float16         None         None      False
#
# [260 rows x 13 columns]

# %%
print(llm_perf.info())
print(ml_energy.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268 entries, 0 to 267
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        268 non-null    int64
#  1   model             268 non-null    object
#  2   throughput        268 non-null    float64
#  3   response_length   268 non-null    int64
#  4   latency           268 non-null    float64
#  5   energy            268 non-null    float64
#  6   gpu               268 non-null    object
#  7   task              268 non-null    object
#  8   parameters_count  268 non-null    float64
#  9   energy_per_token  268 non-null    float64
#  10  dtype             268 non-null    object
#  11  optimization      0 non-null      float64
#  12  quantization      268 non-null    object
#  13  cuda-fp16         268 non-null    bool
# dtypes: bool(1), float64(6), int64(2), object(5)
# memory usage: 27.6+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   model             260 non-null    object
#  1   throughput        260 non-null    float64
#  2   response_length   260 non-null    float64
#  3   latency           260 non-null    float64
#  4   energy            260 non-null    float64
#  5   gpu               260 non-null    object
#  6   task              260 non-null    object
#  7   parameters_count  260 non-null    int64
#  8   energy_per_token  260 non-null    float64
#  9   dtype             260 non-null    object
#  10  optimization      260 non-null    object
#  11  quantization      260 non-null    object
#  12  cuda-fp16         260 non-null    bool
# dtypes: bool(1), float64(5), int64(1), object(6)
# memory usage: 24.8+ KB
# None

# %% [markdown]
# # Dataset ML Energy

# %%
# différentes valeurs uniques dans la colonne "gpu"
gpu_values = ml_energy['gpu'].unique()
print(gpu_values)
# Out:
# ['A100' 'A40' 'V100']

# %%
# Filtrer le dataset pour chaque GPU
ml_energy_A100 = ml_energy.loc[ml_energy['gpu'] == 'A100']
ml_energy_A40 = ml_energy.loc[ml_energy['gpu'] == 'A40']
ml_energy_V100 = ml_energy.loc[ml_energy['gpu'] == 'V100']

# Afficher les datasets pour chaque GPU
print("Dataset pour le GPU A100:")
display(ml_energy_A100)
print("\n")

print("Dataset pour le GPU A40:")
display(ml_energy_A40)
print("\n")

print("Dataset pour le GPU V100:")
display(ml_energy_V100)
print("\n")
# Out:
# Dataset pour le GPU A100:
#                                               model  throughput  \
# 0                                    BAIR/koala-13b   25.501170
# 1                                     BAIR/koala-7b   32.927217
# 2                                RWKV/rwkv-raven-7b   64.478527
# 3          FreedomIntelligence/phoenix-inst-chat-7b   54.276457
# 4                  camel-ai/CAMEL-13B-Combined-Data   26.300221
# ..                                              ...         ...
# 79  openaccess-ai-collective/manticore-13b-chat-pyg   26.222450
# 80                        project-baize/baize-v2-7B   32.410734
# 81                              tatsu-lab/alpaca-7B   25.793786
# 82        togethercomputer/RedPajama-INCITE-7B-Chat   27.400950
# 83                       Salesforce/xgen-7b-8k-inst   48.578756
#
#     response_length    latency       energy   gpu          task  \
# 0        258.854265  10.063551  1946.198744  A100  chat-concise
# 1        247.045668   7.462044  1195.704790  A100  chat-concise
# 2        209.478845   2.921289   736.655330  A100  chat-concise
# 3        233.511081   4.103907  1002.328573  A100  chat-concise
# 4        282.480188  10.727640  2349.183088  A100  chat-concise
# ..              ...        ...          ...   ...           ...
# 79       275.881800  10.469823  2115.522392  A100      instruct
# 80       300.908664   9.142082  1529.693656  A100      instruct
# 81       127.342176   4.787391   727.924359  A100      instruct
# 82       283.261585   9.932343  1629.655867  A100      instruct
# 83       273.659503   5.678087  1209.062228  A100      instruct
#
#     parameters_count  energy_per_token    dtype optimization quantization  \
# 0                 13          0.002088  float16         None         None
# 1                  7          0.001344  float16         None         None
# 2                  7          0.000977  float16         None         None
# 3                  7          0.001192  float16         None         None
# 4                 13          0.002310  float16         None         None
# ..               ...               ...      ...          ...          ...
# 79                13          0.002130  float16         None         None
# 80                 7          0.001412  float16         None         None
# 81                 7          0.001588  float16         None         None
# 82                 7          0.001598  float16         None         None
# 83                 7          0.001227  float16         None         None
#
#     cuda-fp16
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# ..        ...
# 79      False
# 80      False
# 81      False
# 82      False
# 83      False
#
# [84 rows x 13 columns]
# Dataset pour le GPU A40:
#                                    model  throughput  response_length  \
# 84                       lmsys/vicuna-7B   29.829027       271.910007
# 85   StabilityAI/stablelm-tuned-alpha-7b   26.573930       255.543653
# 86               databricks/dolly-v2-12b   15.273711       141.444594
# 87                   tatsu-lab/alpaca-7B   29.852724       121.292814
# 88      camel-ai/CAMEL-13B-Combined-Data   17.460563       283.454332
# ..                                   ...         ...              ...
# 171                       BAIR/koala-13b   17.468010       254.085292
# 172                      metaai/llama-7B   26.402442       104.193083
# 173           metaai/Llama-2-13b-chat-hf   16.999960       371.563130
# 174            metaai/Llama-2-7b-chat-hf   31.815139       365.403627
# 175           Salesforce/xgen-7b-8k-inst   30.891816       274.673606
#
#        latency       energy  gpu          task  parameters_count  \
# 84    9.132098  2143.525612  A40  chat-concise                 7
# 85    9.397492  2439.293790  A40  chat-concise                 7
# 86    8.891394  2095.392226  A40  chat-concise                12
# 87    4.036161  1080.588409  A40  chat-concise                 7
# 88   16.286153  4262.537929  A40  chat-concise                13
# ..         ...          ...  ...           ...               ...
# 171  14.491339  3858.416871  A40      instruct                13
# 172   3.608984   864.418175  A40      instruct                 7
# 173  21.688517  4210.194823  A40      instruct                13
# 174  11.316028  2180.247805  A40      instruct                 7
# 175   8.955941  2099.338152  A40      instruct                 7
#
#      energy_per_token    dtype optimization quantization  cuda-fp16
# 84           0.002190  float16         None         None      False
# 85           0.002652  float16         None         None      False
# 86           0.004115  float16         None         None      False
# 87           0.002475  float16         None         None      False
# 88           0.004177  float16         None         None      False
# ..                ...      ...          ...          ...        ...
# 171          0.004218  float16         None         None      False
# 172          0.002305  float16         None         None      False
# 173          0.003148  float16         None         None      False
# 174          0.001657  float16         None         None      False
# 175          0.002123  float16         None         None      False
#
# [92 rows x 13 columns]
# Dataset pour le GPU V100:
#                                 model  throughput  response_length    latency  \
# 176  camel-ai/CAMEL-13B-Combined-Data   21.431018       280.880121  13.064449
# 177         lmsys/fastchat-t5-3b-v1.0   17.265045       310.343183  23.454800
# 178                  lmsys/vicuna-13B   21.221114       268.287777  12.474879
# 179                   lmsys/vicuna-7B   33.192207       273.571189   8.184472
# 180                   metaai/llama-7B   23.929461        68.058428   2.280900
# ..                                ...         ...              ...        ...
# 255                   metaai/llama-7B   23.642990       110.302552   3.730666
# 256               tatsu-lab/alpaca-7B   31.257538       127.870047   3.985343
# 257                     BAIR/koala-7b   31.414144       253.603761   7.832867
# 258                RWKV/rwkv-raven-7b   39.939984       246.796508   5.837914
# 259        Salesforce/xgen-7b-8k-inst   37.606060       273.058764   7.299936
#
#           energy   gpu          task  parameters_count  energy_per_token  \
# 176  2699.068024  V100  chat-concise                13          0.002669
# 177  1043.990802  V100  chat-concise                 3          0.000934
# 178  2412.714353  V100  chat-concise                13          0.002498
# 179  1387.838511  V100  chat-concise                 7          0.001409
# 180   354.656095  V100  chat-concise                 7          0.001448
# ..           ...   ...           ...               ...               ...
# 255   636.401785  V100      instruct                 7          0.001603
# 256   671.828829  V100      instruct                 7          0.001459
# 257  1181.363735  V100      instruct                 7          0.001294
# 258  1302.030667  V100      instruct                 7          0.001465
# 259  1329.685454  V100      instruct                 7          0.001353
#
#        dtype optimization quantization  cuda-fp16
# 176  float16         None         None      False
# 177  float16         None         None      False
# 178  float16         None         None      False
# 179  float16         None         None      False
# 180  float16         None         None      False
# ..       ...          ...          ...        ...
# 255  float16         None         None      False
# 256  float16         None         None      False
# 257  float16         None         None      False
# 258  float16         None         None      False
# 259  float16         None         None      False
#
# [84 rows x 13 columns]

# %% [markdown]
# # Estimer la latence à partir du nombre de tokens et de la taille du modèle.

# %%
parameters_count_A100 = ml_energy_A100['parameters_count'].unique()
print("Valeurs uniques pour le dataset GPU A100 :")
print(parameters_count_A100)
# Out:
# Valeurs uniques pour le dataset GPU A100 :
# [13  7 12  3]

# %%
parameters_count_A40 = ml_energy_A40['parameters_count'].unique()
print("Valeurs uniques pour le dataset GPU A40 :")
print(parameters_count_A40)
# Out:
# Valeurs uniques pour le dataset GPU A40 :
# [ 7 12 13  3]

# %%
parameters_count_V100 = ml_energy_V100['parameters_count'].unique()
print("Valeurs uniques pour le dataset GPU V100 :")
print(parameters_count_V100)
# Out:
# Valeurs uniques pour le dataset GPU V100 :
# [13  3  7 12]

# %% [markdown]
# # Cas GPU A100

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import seaborn as sns
import matplotlib.pyplot as plt

parameters_counts = [7, 12, 13, 3]

for count in parameters_counts:
    ml_energy_A100_count = ml_energy_A100[ml_energy_A100['parameters_count'] == count]

    regression_count = LinearRegression()
    X_count = ml_energy_A100_count[['response_length']]
    y_count = ml_energy_A100_count['latency']
    regression_count.fit(X_count, y_count)

    correlation_count = ml_energy_A100_count[[
        'response_length', 'latency']].corr()

    print(
        f"Régression linéaire pour le dataset GPU A100 avec parameters_count={count}:")
    print("Coefficient:", regression_count.coef_)
    print("Intercept:", regression_count.intercept_)
    print("\n")
    print(
        f"Matrice de corrélation pour le dataset GPU A100 avec parameters_count={count}:")
    print(correlation_count)
    print("\n")

    sns.pairplot(ml_energy_A100_count[['response_length', 'latency']])
    plt.show()
# Out:
# Régression linéaire pour le dataset GPU A100 avec parameters_count=7:
# Coefficient: [0.02842299]
# Intercept: -0.21436502747332398
#
#
# Matrice de corrélation pour le dataset GPU A100 avec parameters_count=7:
#                  response_length  latency
# response_length           1.0000   0.7504
# latency                   0.7504   1.0000
# /home/lenovo/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Régression linéaire pour le dataset GPU A100 avec parameters_count=12:
# Coefficient: [0.02980389]
# Intercept: 2.299119402441697
#
#
# Matrice de corrélation pour le dataset GPU A100 avec parameters_count=12:
#                  response_length  latency
# response_length          1.00000  0.88836
# latency                  0.88836  1.00000
# /home/lenovo/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Régression linéaire pour le dataset GPU A100 avec parameters_count=13:
# Coefficient: [0.04250026]
# Intercept: -0.5220733294156119
#
#
# Matrice de corrélation pour le dataset GPU A100 avec parameters_count=13:
#                  response_length   latency
# response_length         1.000000  0.964369
# latency                 0.964369  1.000000
# /home/lenovo/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Régression linéaire pour le dataset GPU A100 avec parameters_count=3:
# Coefficient: [0.03155619]
# Intercept: 7.333477008414835
#
#
# Matrice de corrélation pour le dataset GPU A100 avec parameters_count=3:
#                  response_length   latency
# response_length         1.000000  0.217885
# latency                 0.217885  1.000000
# /home/lenovo/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Cas GPU A40

# %%
parameters_counts = [7, 12, 13, 3]

for count in parameters_counts:
    ml_energy_A40_count = ml_energy_A40[ml_energy_A40['parameters_count'] == count]

    regression_count = LinearRegression()
    X_count = ml_energy_A40_count[['response_length']]
    y_count = ml_energy_A40_count['latency']
    regression_count.fit(X_count, y_count)

    correlation_count = ml_energy_A40_count[[
        'response_length', 'latency']].corr()

    print(
        f"Régression linéaire pour le dataset GPU A40 avec parameters_count={count}:")
    print("Coefficient:", regression_count.coef_)
    print("Intercept:", regression_count.intercept_)
    print("\n")
    print(
        f"Matrice de corrélation pour le dataset GPU A40 avec parameters_count={count}:")
    print(correlation_count)
    print("\n")

    sns.pairplot(ml_energy_A40_count[['response_length', 'latency']])
    plt.show()
# Out:
# Régression linéaire pour le dataset GPU A40 avec parameters_count=7:
# Coefficient: [0.03531958]
# Intercept: -0.08871215356480455
#
#
# Matrice de corrélation pour le dataset GPU A40 avec parameters_count=7:
#                  response_length   latency
# response_length         1.000000  0.843067
# latency                 0.843067  1.000000
# /home/lenovo/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Régression linéaire pour le dataset GPU A40 avec parameters_count=12:
# Coefficient: [0.06364188]
# Intercept: -0.23362072444880688
#
#
# Matrice de corrélation pour le dataset GPU A40 avec parameters_count=12:
#                  response_length  latency
# response_length           1.0000   0.9856
# latency                   0.9856   1.0000
# /home/lenovo/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Régression linéaire pour le dataset GPU A40 avec parameters_count=13:
# Coefficient: [0.05795408]
# Intercept: -0.05148254072886793
#
#
# Matrice de corrélation pour le dataset GPU A40 avec parameters_count=13:
#                  response_length   latency
# response_length         1.000000  0.999488
# latency                 0.999488  1.000000
# /home/lenovo/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Régression linéaire pour le dataset GPU A40 avec parameters_count=3:
# Coefficient: [0.08886795]
# Intercept: -11.90674753953698
#
#
# Matrice de corrélation pour le dataset GPU A40 avec parameters_count=3:
#                  response_length   latency
# response_length         1.000000  0.723996
# latency                 0.723996  1.000000
# /home/lenovo/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Cas GPU V100

# %%
parameters_counts = [7, 12, 13, 3]

for count in parameters_counts:
    ml_energy_V100_count = ml_energy_V100[ml_energy_V100['parameters_count'] == count]

    regression_count = LinearRegression()
    X_count = ml_energy_V100_count[['response_length']]
    y_count = ml_energy_V100_count['latency']
    regression_count.fit(X_count, y_count)

    correlation_count = ml_energy_V100_count[[
        'response_length', 'latency']].corr()

    print(
        f"Régression linéaire pour le dataset GPU V100 avec parameters_count={count}:")
    print("Coefficient:", regression_count.coef_)
    print("Intercept:", regression_count.intercept_)
    print("\n")
    print(
        f"Matrice de corrélation pour le dataset GPU V100 avec parameters_count={count}:")
    print(correlation_count)
    print("\n")

    sns.pairplot(ml_energy_V100_count[['response_length', 'latency']])
    plt.show()
# Out:
# Régression linéaire pour le dataset GPU V100 avec parameters_count=7:
# Coefficient: [0.03326262]
# Intercept: -0.5167512466558639
#
#
# Matrice de corrélation pour le dataset GPU V100 avec parameters_count=7:
#                  response_length   latency
# response_length         1.000000  0.856859
# latency                 0.856859  1.000000
# /home/lenovo/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Régression linéaire pour le dataset GPU V100 avec parameters_count=12:
# Coefficient: [0.0626834]
# Intercept: 0.22782403828293596
#
#
# Matrice de corrélation pour le dataset GPU V100 avec parameters_count=12:
#                  response_length   latency
# response_length         1.000000  0.999807
# latency                 0.999807  1.000000
# /home/lenovo/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Régression linéaire pour le dataset GPU V100 avec parameters_count=13:
# Coefficient: [0.04524021]
# Intercept: 0.21987976905771411
#
#
# Matrice de corrélation pour le dataset GPU V100 avec parameters_count=13:
#                  response_length   latency
# response_length         1.000000  0.999624
# latency                 0.999624  1.000000
# /home/lenovo/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Régression linéaire pour le dataset GPU V100 avec parameters_count=3:
# Coefficient: [0.03199498]
# Intercept: 9.77889823333456
#
#
# Matrice de corrélation pour le dataset GPU V100 avec parameters_count=3:
#                  response_length  latency
# response_length           1.0000   0.2178
# latency                   0.2178   1.0000
# /home/lenovo/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Certianes conclusions
#
# # En analysant les résultats des régressions linéaires et des matrices de corrélation pour les trois cas de GPU (A40, A100, V100) avec différentes valeurs de parameters_count, voici quelques conclusions que l'on peut tirer :
#
# # Corrélation entre la longueur de la réponse et la latence :
#
# # Dans tous les cas, il existe une corrélation positive entre la longueur de la réponse (response_length) et la latence (latency). Cela signifie que lorsque la longueur de la réponse augmente, la latence a tendance à augmenter également.
#
# # Influence de la complexité du modèle (parameters_count) sur la corrélation :
#
# # Plus la valeur de parameters_count est élevée, plus la corrélation entre la longueur de la réponse et la latence est forte. Cela suggère que pour des modèles plus complexes, la longueur de la réponse a une influence plus importante sur la latence.
#
# # Comparaison entre les GPU :
#
#
# # Les corrélations et les coefficients de régression sont similaires pour les trois GPU étudiés. Cependant, les valeurs spécifiques peuvent varier légèrement d'un GPU à l'autre.
#
# # Le GPU V100 semble montrer une corrélation légèrement plus faible entre la longueur de la réponse et la latence par rapport aux GPU A40 et A100, en particulier pour des modèles moins complexes (parameters_count=3).
